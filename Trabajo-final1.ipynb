# %% [markdown]
# 1. Estructura

# %%
inventario = []
clientes = {}
ventas_totales = 0

# %% [markdown]
# 2. Funciones

# %%
# 2.1
def agregar_producto(nombre, precio, cantidad):
    producto_existe = False
    for producto in inventario:
        if producto["nombre"] == nombre:
           producto_existe = True
           producto["cantidad"] = producto["cantidad"] + cantidad
    
    if producto_existe == False:
        inventario.append({"nombre":nombre, "precio":precio, "cantidad":cantidad})
    return

# %%
nombre_nuevo = input("¿Dime el nombre del producto?")
precio_nuevo = int(input("pon el precio del producto"))
cantidad_nuevo = int(input("Dime la cantidad del producto")) 

agregar_producto(nombre_nuevo, precio_nuevo, cantidad_nuevo)

inventario
# Out:
# [{'nombre': 'camisa', 'precio': 20, 'cantidad': 2},
#  {'nombre': 'bufanda', 'precio': 4, 'cantidad': 2},
#  {'nombre': 'zapatos', 'precio': 50, 'cantidad': 70}]

# %%
# 2.2
def ver_inventario():
    for producto in inventario:
        print("Nombre:",producto["nombre"].capitalize(), ", Precio: $",producto["precio"], ", Cantidad:",producto["cantidad"] )
    return

# %%
ver_inventario()
# Out:
# Nombre: Camisa , Precio: $ 20 , Cantidad: 3
# Nombre: Bufanda , Precio: $ 4 , Cantidad: 2
# Nombre: Zapatos , Precio: $ 50 , Cantidad: 70

# %%
# 2.3
def buscar_producto(nombre):
    for producto in inventario:
        if producto["nombre"] == nombre:
            print("Nombre:",producto["nombre"].capitalize(), ", Precio: $",producto["precio"], ", Cantidad:",producto["cantidad"])

# %%
buscar_producto("zapatos")
# Out:
# Nombre: Zapatos , Precio: $ 50 , Cantidad: 70

# %%
#2.4
def actualizar_stock(nombre, cantidad):
    producto_existe = False
    for producto in inventario:
        if producto["nombre"] == nombre:
           producto_existe = True
           producto["cantidad"] = producto["cantidad"] + cantidad
    
    if producto_existe == False:
        print("Este producto no existe")
    return

# %%
actualizar_stock("pantalon", 1)
# Out:
# Producto no existente
